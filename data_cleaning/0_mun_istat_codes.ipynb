# %%
import pandas as pd
from functions import normalize_name, add_zeroes

# %%
df = pd.read_csv('C:/Users/HP/Desktop/Traineeship/data/Elenco dei codici e delle denominazioni delle unit_ territoriali.csv', sep = ';')

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7896 entries, 0 to 7895
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Codice Ripartizione geografica  7896 non-null   int64
#  1   Codice Regione                  7896 non-null   int64
#  2   Codice Provincia (Storico)      7896 non-null   int64
#  3   Codice Provincia/Uts            7896 non-null   int64
#  4   Codice Comune (alfanumerico)    7896 non-null   int64
#  5   Codice Comune (numerico)        7896 non-null   int64
#  6   Comune                          7895 non-null   object
#  7   Comune (dizione italiana)       7895 non-null   object
#  8   Comune (dizione straniera)      124 non-null    object
#  9   Ripartizione geografica         7896 non-null   object
#  10  Regione                         7896 non-null   object
#  11  Provincia/Uts                   7896 non-null   object
#  12  Flag tipo Uts                   7896 non-null   int64
#  13  Capoluogo di regione            7896 non-null   int64
#  14  Capoluogo di provincia/uts      7896 non-null   int64
#  15  Sigla automobilistica           7804 non-null   object
#  16  Codice catasto                  7896 non-null   object
#  17  Codice fiscale                  7896 non-null   int64
#  18  Codice NUTS1 2024               7896 non-null   object
#  19  Codice NUTS2 2024               7896 non-null   object
#  20  Codice NUTS3 2024               7896 non-null   object
# dtypes: int64(10), object(11)
# memory usage: 1.3+ MB

# %%
df.head()
# Out:
#    Codice Ripartizione geografica  Codice Regione  Codice Provincia (Storico)  \
# 0                               1               1                           1
# 1                               1               1                           1
# 2                               1               1                           1
# 3                               1               1                           1
# 4                               1               1                           1
#
#    Codice Provincia/Uts  Codice Comune (alfanumerico)  \
# 0                   201                          1001
# 1                   201                          1002
# 2                   201                          1003
# 3                   201                          1004
# 4                   201                          1006
#
#    Codice Comune (numerico)           Comune Comune (dizione italiana)  \
# 0                      1001            Agliè                     Agliè
# 1                      1002          Airasca                   Airasca
# 2                      1003     Ala di Stura              Ala di Stura
# 3                      1004  Albiano d'Ivrea           Albiano d'Ivrea
# 4                      1006           Almese                    Almese
#
#   Comune (dizione straniera) Ripartizione geografica  ... Provincia/Uts  \
# 0                        NaN              Nord-ovest  ...        Torino
# 1                        NaN              Nord-ovest  ...        Torino
# 2                        NaN              Nord-ovest  ...        Torino
# 3                        NaN              Nord-ovest  ...        Torino
# 4                        NaN              Nord-ovest  ...        Torino
#
#   Flag tipo Uts  Capoluogo di regione  Capoluogo di provincia/uts  \
# 0             3                     0                           0
# 1             3                     0                           0
# 2             3                     0                           0
# 3             3                     0                           0
# 4             3                     0                           0
#
#    Sigla automobilistica Codice catasto Codice fiscale  Codice NUTS1 2024  \
# 0                     TO           A074    83501790014                ITC
# 1                     TO           A109    85002910017                ITC
# 2                     TO           A117    83002970016                ITC
# 3                     TO           A157     1735420018                ITC
# 4                     TO           A218     1817670019                ITC
#
#   Codice NUTS2 2024 Codice NUTS3 2024
# 0              ITC1             ITC11
# 1              ITC1             ITC11
# 2              ITC1             ITC11
# 3              ITC1             ITC11
# 4              ITC1             ITC11
#
# [5 rows x 21 columns]

# %%
dict = {
    'Comune':'mun_name',
    'Provincia/Uts' : 'prov_name',
    'Codice Comune (alfanumerico)':'mun_istat',
    'Codice Provincia (Storico)' : 'prov_istat',
    'Regione' : 'reg_name'
}

df = df.rename(columns = dict)

# %%
# Order columns
order = ['mun_name','prov_name','mun_istat','prov_istat','reg_name']

df = df[order]

# %%
# Add missing heading 0s to Istat codes
add_zeroes(df, ['mun_istat'], 6)

df['mun_istat'] = df['mun_istat'].astype('object')

# Add missing heading 0s to provincial Istat codes
add_zeroes(df, ['prov_istat'], 3)

df['prov_istat'] = df['prov_istat'].astype('object')


# Normalize municipalities, province, and region names
col_to_norm = ['mun_name','prov_name','reg_name']

for col in col_to_norm:
    df[col + '_norm'] = df[col].apply(normalize_name).astype('object')

# %%
# Check for duplicates
df[df['mun_name_norm'].duplicated(keep=False)].sort_values('mun_name_norm')
# Out:
#          mun_name                  prov_name mun_istat prov_istat  \
# 1894       Castro                    Bergamo    016065        016
# 6057       Castro                      Lecce    075096        075
# 1552         Livo                       Como    013130        013
# 2822         Livo                     Trento    022106        022
# 6159      Paterno                    Potenza    076100        076
# 6850      Paternò                    Catania    087033        087
# 1577       Peglio                       Como    013178        013
# 3983       Peglio            Pesaro e Urbino    041041        041
# 230        Samone                     Torino    001235        001
# 2863       Samone                     Trento    022165        022
# 6714  San Teodoro                    Messina    083090        083
# 7605  San Teodoro  Gallura Nord-Est Sardegna    113021        113
#
#                           reg_name mun_name_norm            prov_name_norm  \
# 1894                     Lombardia        castro                   bergamo
# 6057                        Puglia        castro                     lecce
# 1552                     Lombardia          livo                      como
# 2822  Trentino-Alto Adige/Südtirol          livo                    trento
# 6159                    Basilicata       paterno                   potenza
# 6850                       Sicilia       paterno                   catania
# 1577                     Lombardia        peglio                      como
# 3983                        Marche        peglio           pesaro e urbino
# 230                       Piemonte        samone                    torino
# 2863  Trentino-Alto Adige/Südtirol        samone                    trento
# 6714                       Sicilia   san teodoro                   messina
# 7605                      Sardegna   san teodoro  gallura nordest sardegna
#
#                    reg_name_norm
# 1894                   lombardia
# 6057                      puglia
# 1552                   lombardia
# 2822  trentinoalto adigesudtirol
# 6159                  basilicata
# 6850                     sicilia
# 1577                   lombardia
# 3983                      marche
# 230                     piemonte
# 2863  trentinoalto adigesudtirol
# 6714                     sicilia
# 7605                    sardegna

# %%
# Create a key [mun_name,region] to uniquely identify duplicates
df['mun_key'] = df['mun_name_norm'] + '_' + df['reg_name_norm']

# %%
# Check for duplicates
df[df['mun_key'].duplicated(keep=False)].sort_values('mun_key')
# Out:
# Empty DataFrame
# Columns: [mun_name, prov_name, mun_istat, prov_istat, reg_name, mun_name_norm, prov_name_norm, reg_name_norm, mun_key]
# Index: []

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7896 entries, 0 to 7895
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mun_name        7895 non-null   object
#  1   prov_name       7896 non-null   object
#  2   mun_istat       7896 non-null   object
#  3   prov_istat      7896 non-null   object
#  4   reg_name        7896 non-null   object
#  5   mun_name_norm   7896 non-null   object
#  6   prov_name_norm  7896 non-null   object
#  7   reg_name_norm   7896 non-null   object
#  8   mun_key         7896 non-null   object
# dtypes: object(9)
# memory usage: 555.3+ KB

# %%
df.to_parquet('datasets/mun_istat_codes.parquet', index = False)
