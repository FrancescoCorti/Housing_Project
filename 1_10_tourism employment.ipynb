# %%
import pandas as pd

# %%
df = pd.read_excel('C:/Users/HP/Desktop/Traineeship/data/UN_Tourism_8_9_2_employed_persons_10_2025.xlsx', sheet_name = 'Data')

# %%
df = df.loc[(df['reporter_area_label'] == 'Italy') & (df['indicator_label'] == 'employment in tourism industries - total - total - total - total - persons')]

df = df[['year', 'value']]

df = df.rename(columns = {'value':'tour_employed'})

# %%
df.to_parquet('datasets/tourism_employment.parquet', index = False)
